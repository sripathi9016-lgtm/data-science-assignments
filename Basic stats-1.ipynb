# %%
# 📘 Descriptive Analytics & Visualization Code
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("sales_data_with_discounts.csv")

# %%
#  1 Select only numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("Numerical Columns:", list(num_cols))
# Out:
# Numerical Columns: ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']

# %%
# 2️ Descriptive Statistics
desc_stats = pd.DataFrame({
    'Mean': df[num_cols].mean(),
    'Median': df[num_cols].median(),
    'Mode': df[num_cols].mode().iloc[0],
    'Standard Deviation': df[num_cols].std()
})
print("\n=== Basic Statistics ===")
print(desc_stats)
# Out:
# === Basic Statistics ===
#                            Mean       Median          Mode  Standard Deviation
# Volume                 5.066667     4.000000      3.000000            4.231602
# Avg Price          10453.433333  1450.000000    400.000000        18079.904840
# Total Sales Value  33812.835556  5700.000000  24300.000000        50535.074173
# Discount Rate (%)     15.155242    16.577766      5.007822            4.220602
# Discount Amount     3346.499424   988.933733     69.177942         4509.902963
# Net Sales Value    30466.336131  4677.788059    326.974801        46358.656624

# %%
# 3️ Interpretation Example
print("\nInterpretation:")
for col in num_cols:
    print(f"- {col}: Mean = {df[col].mean():.2f}, Std Dev = {df[col].std():.2f}")
# Out:
# Interpretation:
# - Volume: Mean = 5.07, Std Dev = 4.23
# - Avg Price: Mean = 10453.43, Std Dev = 18079.90
# - Total Sales Value: Mean = 33812.84, Std Dev = 50535.07
# - Discount Rate (%): Mean = 15.16, Std Dev = 4.22
# - Discount Amount: Mean = 3346.50, Std Dev = 4509.90
# - Net Sales Value: Mean = 30466.34, Std Dev = 46358.66

# %%
# 4️ Histograms for each numerical column
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True, color='blue', bins=20)
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# 5️ Boxplots for each numerical column
for col in num_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col], color='orange')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.tight_layout()
    plt.show()

# %%
# 6️ Bar charts for categorical columns
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    plt.figure(figsize=(6,4))
    df[col].value_counts().plot(kind='bar', color='green')
    plt.title(f'Bar Chart of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

# %%
# 7️ Summary Conclusion (printed)
print("\n=== Conclusion ===")
print("The dataset's descriptive analytics revealed key patterns in sales and discount behavior.")
print("Histograms show distribution trends; boxplots helped detect outliers; bar charts highlight category frequencies.")
# Out:
# === Conclusion ===
# The dataset's descriptive analytics revealed key patterns in sales and discount behavior.
# Histograms show distribution trends; boxplots helped detect outliers; bar charts highlight category frequencies.
